# %%
import pandas as pn
import numpy as np
import matplotlib.pyplot as mtl
import seaborn as sns

# %%
s= pn.read_csv(r"C:\500000 Sales Records.csv")

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
s.describe
# Out:
# <bound method NDFrame.describe of                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
# ...

# %%
s.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Region          500000 non-null  object
#  1   Country         500000 non-null  object
#  2   Item Type       500000 non-null  object
#  3   Sales Channel   500000 non-null  object
#  4   Order Priority  500000 non-null  object
#  5   Order Date      500000 non-null  object
#  6   Order ID        500000 non-null  int64
#  7   Ship Date       500000 non-null  object
#  8   Units Sold      500000 non-null  int64
#  9   Unit Price      500000 non-null  float64
#  10  Unit Cost       500000 non-null  float64
#  11  Total Revenue   500000 non-null  float64
#  12  Total Cost      500000 non-null  float64
#  13  Total Profit    500000 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 53.4+ MB

# %%
s.head(11)
# Out:
#                           Region           Country        Item Type  \
# 0             Sub-Saharan Africa      South Africa           Fruits
# 1   Middle East and North Africa           Morocco          Clothes
# 2          Australia and Oceania  Papua New Guinea             Meat
# 3             Sub-Saharan Africa          Djibouti          Clothes
# 4                         Europe          Slovakia        Beverages
# 5                           Asia         Sri Lanka           Fruits
# 6             Sub-Saharan Africa       Seychelles         Beverages
# 7             Sub-Saharan Africa          Tanzania        Beverages
# 8             Sub-Saharan Africa             Ghana  Office Supplies
# 9             Sub-Saharan Africa          Tanzania        Cosmetics
# 10                          Asia            Taiwan           Fruits
#
#    Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# 0        Offline              M   7/27/2012  443368995   7/28/2012
# ...

# %%
s.tail(12)
# Out:
#                                    Region               Country  \
# 499988  Central America and the Caribbean             Guatemala
# 499989                             Europe              Slovenia
# 499990                             Europe              Moldova
# 499991                 Sub-Saharan Africa            Mauritania
# 499992                             Europe                Monaco
# 499993              Australia and Oceania                Tuvalu
# 499994  Central America and the Caribbean  Antigua and Barbuda
# 499995                               Asia               Myanmar
# 499996              Australia and Oceania           New Zealand
# 499997                             Europe             Lithuania
# 499998                               Asia              Malaysia
# 499999                             Europe              Slovakia
#
#               Item Type Sales Channel Order Priority  Order Date   Order ID  \
# ...

# %%
s[["Region","Total Profit"]]
# Out:
#                               Region  Total Profit
# 0                 Sub-Saharan Africa       3839.13
# 1       Middle East and North Africa     338631.84
# 2              Australia and Oceania      20592.00
# 3                 Sub-Saharan Africa      41273.28
# 4                             Europe      62217.18
# ...                              ...           ...
# 499995                          Asia        433.80
# 499996         Australia and Oceania     894607.50
# 499997                        Europe     240079.56
# 499998                          Asia     133924.32
# 499999                        Europe    1371747.21
#
# [500000 rows x 2 columns]

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
s.isnull()
# Out:
#         Region  Country  Item Type  Sales Channel  Order Priority  Order Date  \
# 0        False    False      False          False           False       False
# 1        False    False      False          False           False       False
# 2        False    False      False          False           False       False
# 3        False    False      False          False           False       False
# 4        False    False      False          False           False       False
# ...        ...      ...        ...            ...             ...         ...
# 499995   False    False      False          False           False       False
# 499996   False    False      False          False           False       False
# 499997   False    False      False          False           False       False
# 499998   False    False      False          False           False       False
# 499999   False    False      False          False           False       False
#
# ...

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
# How many unique products and regions are there?
s["Item Type"].unique(),s["Region"].unique()
s["Item Type"].nunique(),s["Region"].nunique()
# Out:
# (12, 7)

# %%
# What is the correlation between Quantity and Sales?
s[["Units Sold","Order ID"]].corr()
# Out:
#             Units Sold  Order ID
# Units Sold    1.000000 -0.001064
# Order ID     -0.001064  1.000000

# %%
# Which region has the highest total profit?
s.groupby("Region")["Total Profit"].mean().sort_values(ascending=False).head(1)
# Out:
# Region
# North America    394070.17137
# Name: Total Profit, dtype: float64

# %%
#What is the total profit across all records?
s["Total Profit"].sum()
# Out:
# np.float64(196239982294.22006)

# %%
# Are there any missing values in the dataset?
s.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
# How many total records are in the dataset?.
len(s)
# Out:
# 500000

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
# Q1. Which region has the highest total revenue?
s.groupby("Region")["Total Revenue"].max().value_counts().sort_values(ascending=False).head(1)
# Out:
# Total Revenue
# 6682031.73    2
# Name: count, dtype: int64

# %%
# Q2. Which country generated the highest total profit?
s.groupby("Country")["Total Profit"].max().value_counts().sort_values(ascending=False).head(1)
# Out:
# Total Profit
# 1737482.91    8
# Name: count, dtype: int64

# %%
# Q3. Which item type is sold the most (by units)?
s.groupby("Item Type")["Units Sold"].sum().sort_values(ascending=False).head(1)
# Out:
# Item Type
# Personal Care    209288730
# Name: Units Sold, dtype: int64

# %%
# Q4. What is the overall profit margin (%)?
t_r=s["Total Revenue"].sum()
t_p=s["Total Profit"].sum()
a  = (t_r)/(t_p) * 100
a
# Out:
# np.float64(338.8953398873132)

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
# Q5 Which sales channel performs better in profit (Online vs Offline)?
s.groupby("Sales Channel")["Total Profit"].sum()
# Out:
# Sales Channel
# Offline    9.815949e+10
# Online     9.808050e+10
# Name: Total Profit, dtype: float64

# %%
# Q6. Which order priority generates the most revenue?
s.groupby("Order Priority")[["Total Revenue","Total Profit"]].sum()
# Out:
#                 Total Revenue  Total Profit
# Order Priority
# C                1.664147e+11  4.913613e+10
# H                1.664532e+11  4.909225e+10
# L                1.661251e+11  4.902765e+10
# M                1.660551e+11  4.898395e+10

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
# Q7. How do unit prices vary across different item types?
s.groupby("Item Type")["Unit Price"].mean().sort_values(ascending=False).head(1)
# Out:
# Item Type
# Household    668.27
# Name: Unit Price, dtype: float64

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
# Q8. Which country/region takes the longest average shipping time?
s["Order Date"] = pn.to_datetime(s["Order Date"])
s["Ship Date"] = pn.to_datetime(s["Ship Date"])
s["Ship Days"] = (s["Ship Date"] - s["Order Date"]).dt.days

ship_time = s.groupby("Region")["Ship Days"].mean().sort_values(ascending=False)
ship_time
# Out:
# Region
# Middle East and North Africa         25.067752
# Asia                                 25.027564
# Australia and Oceania                25.022884
# Europe                               25.003659
# Sub-Saharan Africa                   24.990623
# Central America and the Caribbean    24.919428
# North America                        24.906290
# Name: Ship Days, dtype: float64

# %%
# 9 What is the distribution of order priorities (H, M, L, C)?
s["Order Priority"].value_counts()
# Out:
# Order Priority
# L    125138
# C    125042
# H    124987
# M    124833
# Name: count, dtype: int64

# %%
# 10 What is the average shipping duration (in days) between Order Date and Ship Date?
a=s["Ship Date"].value_counts().mean()
d = s.groupby("Item Type")["Ship Date"].mean().sort_values()
print("Overall avg shipping days:", a)
print("Avg shipping days by region:\n", d)
# Out:
# Overall avg shipping days: 177.5568181818182
# Avg shipping days by region:
#  Item Type
# Fruits            2013-11-06 04:12:23.421936384
# Beverages         2013-11-06 12:38:18.269896192
# Household         2013-11-07 03:51:24.787466752
# Snacks            2013-11-07 16:40:05.179110912
# Clothes           2013-11-08 03:09:04.805584128
# Vegetables        2013-11-08 14:31:13.503780864
# Meat              2013-11-09 04:28:00.397379584
# Baby Food         2013-11-11 00:05:54.667883008
# Cosmetics         2013-11-11 17:58:10.749574400
# Cereal            2013-11-12 07:44:19.583363328
# Office Supplies   2013-11-12 19:52:57.468853760
# Personal Care     2013-11-13 19:07:26.672569344
# Name: Ship Date, dtype: datetime64[ns]

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %% [markdown]
# # GRAPHS

# %%
# 1) Distribution of Order Priorities
region_sales = s.groupby("Region")[["Total Revenue", "Total Profit"]].sum().sort_values("Total Revenue", ascending=False)
region_sales.plot(kind="bar", figsize=(10,6))
mtl.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Sub-Saharan Africa'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Middle East and North Africa'),
#   Text(4, 0, 'Central America and the Caribbean'),
#   Text(5, 0, 'Australia and Oceania'),
#   Text(6, 0, 'North America')])

# %% [markdown]
# Each bar represents a Region (Asia, Europe, etc.).
#
# The bar height tells us the total revenue and total profit from that region.
#
# Example: If Sub-Saharan Africa has a very tall bar in Revenue but shorter in Profit → It means sales are high but profit margins are smaller.

# %%
# 2 
c_r=s.groupby("Country")["Total Revenue"].sum().sort_values(ascending=False).head(10)
sns.barplot(x=c_r,y=c_r.index)
# Out:
# <Axes: xlabel='Total Revenue', ylabel='Country'>

# %% [markdown]
# A horizontal bar chart of Top 10 countries.
#
# The longest bar = country with highest revenue.
#
# Example: If India is at the top, it means India contributes the most money from sales.

# %%
# 3 Online vs Offline Sales
channel_perf = s.groupby("Sales Channel")[["Total Revenue", "Total Profit"]].sum()
channel_perf.plot(kind="bar")
mtl.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'Offline'), Text(1, 0, 'Online')])

# %% [markdown]
# A simple bar chart comparing Online vs Offline.
#
# Two bars for each channel: one for Revenue and one for Profit.
#
# Example: If Offline has higher Revenue but Online has higher Profit, it means online sales are more cost-effective.

# %%
# 4 Order Priority Analysis
q=s.groupby("Order Priority")[["Total Revenue","Total Profit"]].sum()
q.plot(kind="bar")
mtl.xticks(rotation=0)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'C'), Text(1, 0, 'H'), Text(2, 0, 'L'), Text(3, 0, 'M')])

# %% [markdown]
# Bar chart for each Order Priority (L, M, H, C → Low, Medium, High, Critical).
#
# Revenue and Profit compared for each priority.
#
# Example: If High priority orders give the most revenue, the company should process them faster.

# %%
# 5 Shipping Days Distribution
s["Shipping Days"] = (s["Ship Date"] - s["Order Date"]).dt.days
sns.histplot(s["Shipping Days"], bins=30, kde=True)
# Out:
# <Axes: xlabel='Shipping Days', ylabel='Count'>

# %% [markdown]
# A histogram (distribution) of shipping days.
#
# The peak of the graph = the most common shipping time.
#
# Example: If the highest peak is around 30 days, then most orders are delivered in ~1 month.

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
# 6 . Which product has the highest sales revenue?
product_sales = s.groupby("Item Type")["Total Revenue"].sum().sort_values(ascending=False)
product_sales.plot(kind="bar", figsize=(10,5))
mtl.title("Total Sales Revenue by Product")
mtl.ylabel("Revenue")
mtl.xticks(rotation=30)
mtl.show()

# %%
# 7 How do sales vary across different regions?
r=s.groupby("Region")["Total Revenue"].sum().sort_values(ascending=False)
r.plot(kind="bar",color="orange")
mtl.xticks(rotation=30)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6]),
#  [Text(0, 0, 'Sub-Saharan Africa'),
#   Text(1, 0, 'Europe'),
#   Text(2, 0, 'Asia'),
#   Text(3, 0, 'Middle East and North Africa'),
#   Text(4, 0, 'Central America and the Caribbean'),
#   Text(5, 0, 'Australia and Oceania'),
#   Text(6, 0, 'North America')])

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
# 8. . Which Item Type contributes most to revenue
items=s.groupby("Item Type")["Total Revenue"].sum().reset_index()
sns.barplot(data=items,x="Item Type",y="Total Revenue")
mtl.xticks(rotation=45)
mtl.title("Item Type contributes most to revenue")
# Out:
# Text(0.5, 1.0, 'Item Type contributes most to revenue')

# %% [markdown]
# Positive correlation shows that as quantity increases,
# sales increase. Some points may be exceptions due to
# discounts or low-priced items.

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
# 9 How are Total Profits distributed across all orders?
sns.histplot(s["Total Profit"],bins=20,kde=True)
mtl.title(" Total Profits distributed")
# Out:
# Text(0.5, 1.0, ' Total Profits distributed')

# %% [raw]
# Most orders have small-to-moderate profit,
# while very high profits are rare.

# %%
s
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority Order Date   Order ID  Ship Date  \
# ...

# %%
# 10 . Is there a relationship between Units Sold and Total Profit?
sns.scatterplot(data=s,x="Units Sold",y="Total Revenue")
mtl.title(" Rlationship between Units Sold and Total Profit ")
# Out:
# Text(0.5, 1.0, ' Rlationship between Units Sold and Total Profit ')

# %% [raw]
# There is a strong positive relationship between Units Sold and Total Profit, meaning as the number of units sold increases,
# the total profit also tends to rise. This is confirmed by the scatter plot trend and a high positive correlation value.
